# %% [markdown]
# # Analysis of SAT annotations
#
# 9/8/2020
#
# Shahreen Pysche and Javier Osorio
#
# ## Background
#
# This script conducts a preliminary descriptive analysis of human annotations of terrorist activity of the South Asia Terrorism Portal (SATP) between 2016 and 2018.
#
# To code terrorist activity, we will use the guidelines of the Global Terrorism Database (GTD) project.
#
# To conduct the annotations, we count with a team of three human coders that reached a XXXX% of inter-coder reliability in the training stage.
#
# So far, we have completed the following rounds of annotations:
# * Round 1: 1,500 stories (each coder has 500 stories)
# * Round 2: 1,500 stories (each coder has 500 stories)
# * Round 3: in progress
# * Total up today: **3,000**
#
#
# ## Load the necessary libraries

# %%
"""

    * Pandas is a software library written for the Python programming language for data manipulation and analysis.
    * Matplotlib & seaborn are plotting libraries.
    * NumPy is a library for the Python programming language, adding support for large, multi-dimensional arrays 
      and matrices, along with a large collection of high-level mathematical functions to operate on these arrays.
    * csv is a library which helps to process csv files.
    * collections is a library which supports some external data structures.

"""

# Importing libraries for analyzing the annotated SATP news reports

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import csv
import collections
sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(20,13)})
plt.style.use('ggplot')

# %%
# Defining an array which holds the names of the components of the events

EVENTS = ['target', 'source', 'action', 'location', 'date', 'action_type', 'target_group', 'action_group', 'source_group']

# %% [markdown]
# ## Data Processing Functions
#
# First, we need to define a set of functions that will help us process the data later on.
#
# * **process_column**: This function converts the string into arrays and fills in NAs
# * **proceess_text**: This function cleans extra spaces within the labels
# * **get_unique**: This function deduplicates the content of each cell leaving a unique value

# %%
"""

    This function processes the string to arraytype for each row and also fills up the null values
    
    INPUT - df - Dataframe
            col - Name of the column. The column is a string type column
    

"""
def process_column(df, col):
    df.fillna("NotSpecified", inplace=True)
    df[col] = df[col].str.strip('[]').str.split(',')
    #df[col] = df[col].apply(my_function)
    
"""

    This function processes the text and gets rid off the extra spaces within the labels
    
    Input - Array of Strings
    
    Example - Input - ['  ArmedAssault', 'ArmedAssault  ']
              Output - ['ArmedAssault', 'ArmedAssault']
    
    

"""
def proceess_text(data):
    for i in range(len(data)):
        data[i] = ''.join(c for c in data[i] if c not in '"')
        data[i] = ''.join(c for c in data[i] if c not in '\'')
        data[i] = data[i].strip()

"""

    This function retrives the distinct labels from each row of a particular column
    
    INPUT - Column Values
    
    Example - Input - ['ArmedAssault', 'ArmedAssault']
              Output - ['ArmedAssault']

"""      
        
def get_unique(data):
    for i in range(len(data)):
        # print(data[i])
        proceess_text(data[i])
        data[i] = list(set(data[i]))

# %% [markdown]
# The annotations are currently formatted as an array nested within another array. For example:
#
# [['kidnapped', 'killed'], ['injured']]
#
# This makes it very difficult to work with the data.
#
# The **flatten_list** function "flattens" the annotations to generate an array containing strings, such as:
#
# ['kidnapped', 'killed','injured']

# %%
import itertools
from collections import defaultdict

"""
    
    This function takes an nested list of strings. After that it flattens the entire array. For example,
    [['kidnapped', 'killed'], ['injured']] becomes ['kidnapped', 'killed','injured']. The reason for doing
    this is that we dont want any duplicates. That is why we are getting rid off the redudancies. 
    
    This function also can produce the Top K labels of given column with its respective counts.

"""

def flatten_list(data, K):
    # get_unique(data)
    flatten = list(itertools.chain.from_iterable(data))
    #proceess_text(flatten)
    records = defaultdict(int)
    track = []
    for i in flatten:
        records[i] += 1
    for k, v in records.items():
        track.append((v, k))
    track.sort(key = lambda x : [-x[0]])
    if K > 0:
        track = track[0:K]
    keep = set()
    for i in track:
        keep.add(i[1])
    final_list = []
    for i in flatten:
        if i in keep:
            final_list.append(i)
    return final_list

# %% [markdown]
# ## Read and Check Data

# %% [markdown]
# Import the data from .csv files and create a data frame (df).

# %%
# Importing data from csv file

############## First Round Data ##################
# p1 = pd.read_csv('Data/p1.csv', header=[0])
# p2 = pd.read_csv('Data/p2.csv', header=[0])
# p3 = pd.read_csv('Data/p3.csv', header=[0])

# ############## Second Round Data ##################
# p4 = pd.read_csv('Data/p4.csv', header=[0])
# p5 = pd.read_csv('Data/p5.csv', header=[0])
# p6 = pd.read_csv('Data/p6.csv', header=[0])

# # Concatenate all objects
# df = pd.concat([p1, p2, p3, p4, p5, p6], ignore_index=True)

df = pd.read_csv('master.csv', header=[0])

# %% [markdown]
# Display a few rows of the data

# %%
df.head(5)
# Out:
#       id  is_relevant                                            target  \
# 0  32355         True                    ['Military Police', 'Rangers']
# 1  32398         True           ['civilians', 'Security Forces', 'SFs']
# 2  29171         True                                 ['Naga', 'Nagas']
# 3  25445         True  ['foreigners', 'Artisan Restaurant', 'hostages']
# 4  31739         True               ['MQM', 'Muttahida Qaumi Movement']
#
#                                               source  \
# 0             ['Lashkar e Jhangvi LeJ', 'militants']
# 1                                   ['NotSpecified']
# 2          ['MNPF', 'Manipur Naga Peopleâ€™s Front']
# 3  ['suicide fighters', 'suicide soldiers', 'atta...
# 4                                   ['NotSpecified']
#
#                                          action            action_type  \
# 0               ['killed', 'killing', 'gunned']      ['Armed Assault']
# 1  ['killed', 'killing', 'fighting', 'wounded']            ['Unknown']
# 2   ['explosion', 'attack', 'exploded', 'bomb']  ['Bombing/Explosion']
# 3         ['injuring', 'killing', 'gun battle']      ['Armed Assault']
# 4                                      ['shot']      ['Assassination']
#
#                                        location                date  \
# 0                                   ['Karachi']      ['December 6']
# 1                              ['NotSpecified']     ['December 20']
# 2                              ['NotSpecified']       ['August 30']
# 3                                     ['Dhaka']  ['27th', 'August']
# 4  ['Korangi', 'Karachi', 'Sindh', 'Naeemabad']         ['June 19']
#
#       country  year                                               news  \
# 0    pakistan  2016  Two Lashkar e Jhangvi LeJ militants Asim alias...
# 1    pakistan  2016  The Commander Southern Command Lieutenant Gene...
# 2       india  2016  Meanwhile the underground organization Manipur...
# 3  bangladesh  2016  Islamic State IS in the latest issue of its on...
# 4    pakistan  2016  A senior Muttahida Qaumi Movement MQM worker i...
#
#                                        target_group  \
# 0                    ['Military Police', 'Rangers']
# 1                       ['civilians', 'SFs', 'SFs']
# 2                                  ['Naga', 'Naga']
# 3  ['civilians', 'Artisan Restaurant', 'civilians']
# 4                                    ['MQM', 'MQM']
#
#                                   action_group  \
# 0           ['killed', 'killed', 'gun attack']
# 1  ['killed', 'killed', 'fighting', 'wounded']
# 2   ['exploded', 'attack', 'exploded', 'bomb']
# 3          ['injured', 'killed', 'gun attack']
# 4                                     ['shot']
#
#                                         source_group
# 0                               ['LeJ', 'Militants']
# 1                                   ['NotSpecified']
# 2                                   ['MNPF', 'MNPF']
# 3  ['suicide bomber', 'suicide bomber', 'attackers']
# 4                                   ['NotSpecified']

# %% [markdown]
# Show the structure of the data (rows, columns)

# %%
print(df.shape)
# Out:
# (3000, 14)

# %% [markdown]
# Now, create the 'EVENTS' object and conver the strings to arrays

# %%
# process - masteer
for i in EVENTS:
    process_column(df, i)
    get_unique(df[i])
# Out:
# /Users/shahreenshahjahanpsyche/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Show a few rows to see how it is looking

# %%
df.head() # [[ArmedAssault], [Bombing]] --> [ArmedAssault, Bombing]
# Out:
#       id  is_relevant                                      target  \
# 0  32355         True                  [Military Police, Rangers]
# 1  32398         True           [civilians, Security Forces, SFs]
# 2  29171         True                               [Nagas, Naga]
# 3  25445         True  [Artisan Restaurant, hostages, foreigners]
# 4  31739         True             [MQM, Muttahida Qaumi Movement]
#
#                                             source  \
# 0               [Lashkar e Jhangvi LeJ, militants]
# 1                                   [NotSpecified]
# 2            [Manipur Naga Peopleâ€™s Front, MNPF]
# 3  [suicide soldiers, attackers, suicide fighters]
# 4                                   [NotSpecified]
#
#                                  action          action_type  \
# 0             [gunned, killed, killing]      [Armed Assault]
# 1  [fighting, killed, wounded, killing]            [Unknown]
# 2   [explosion, bomb, exploded, attack]  [Bombing/Explosion]
# 3       [injuring, gun battle, killing]      [Armed Assault]
# 4                                [shot]      [Assassination]
#
#                                location            date     country  year  \
# 0                             [Karachi]    [December 6]    pakistan  2016
# 1                        [NotSpecified]   [December 20]    pakistan  2016
# 2                        [NotSpecified]     [August 30]       india  2016
# 3                               [Dhaka]  [August, 27th]  bangladesh  2016
# 4  [Sindh, Naeemabad, Karachi, Korangi]       [June 19]    pakistan  2016
#
#                                                 news  \
# 0  Two Lashkar e Jhangvi LeJ militants Asim alias...
# 1  The Commander Southern Command Lieutenant Gene...
# 2  Meanwhile the underground organization Manipur...
# 3  Islamic State IS in the latest issue of its on...
# 4  A senior Muttahida Qaumi Movement MQM worker i...
#
#                       target_group                   action_group  \
# 0       [Military Police, Rangers]           [gun attack, killed]
# 1                 [civilians, SFs]    [killed, wounded, fighting]
# 2                           [Naga]       [bomb, exploded, attack]
# 3  [civilians, Artisan Restaurant]  [gun attack, killed, injured]
# 4                            [MQM]                         [shot]
#
#                   source_group
# 0             [Militants, LeJ]
# 1               [NotSpecified]
# 2                       [MNPF]
# 3  [suicide bomber, attackers]
# 4               [NotSpecified]

# %% [markdown]
# Show a slice of the data using the 'df.loc' function.
#
# Notice that there are no spaces between words.

# %%
# First term indicates the row (e.g. for row 0 use [0, :])
# The second term indicates the column (e.g. for col 3 use [2]) - counter starts in 0
# Thr third term selects the item of the list within the column (e.g. for first item use [0])

df.loc[0, :][2][0]
# Out:
# 'Military Police'

# %% [markdown]
# # Data Visulization

# %% [markdown]
# ## 1. 0 - Ratio - Relevant vs Not Relevant

# %% [markdown]
# Identify the proportion of relevant and irrelevant news stories.

# %%
# Calculate number of relevant stories
n_relevant = len(df[df['is_relevant'] == True])
n_not_relevant = (3000 - len(df[df['is_relevant'] == True]))

# Calculate proportion of relevant and not relevant
p_relevant = (len(df[df['is_relevant'] == True])/3000)*100
p_not_relevant = ((3000 - len(df[df['is_relevant'] == True]))/3000)*100

# Print results

print('#################################################')
print('Two rounds of annotations led to 3,000 articles')
print('3 URAs x 500 articles x 2 rounds')
print('\n')
print("Number of Relevant news =", n_relevant)
print("Number of Not Relevant news =", n_not_relevant)
print('\n')
print("Proportion of Relevant news =", p_relevant, "%")
print("Proportion of Not Relevant news =", p_not_relevant, "%")
print('\n')
print('#################################################')


df = df[df['is_relevant'] == True]
# Out:
# #################################################
# Two rounds of annotations led to 3,000 articles
# 3 URAs x 500 articles x 2 rounds
#
#
# Number of Relevant news = 504
# Number of Not Relevant news = 2496
#
#
# Proportion of Relevant news = 16.8 %
# Proportion of Not Relevant news = 83.2 %
#
#
# #################################################

# %% [markdown]
# ## 1.1 Event Distribution

# %% [markdown]
# Explore the distribution of events.
#
# The code belows creates a set of objects containing the information of source, action, and target.

# %%
# I am not sure what this does.

K = -1   # K is the number of labels per column, right? But, why is K=-1?

action = flatten_list(df['action_group'].values, K)
target = flatten_list(df['target_group'].values, K)
source = flatten_list(df['source_group'].values, K)
action_type = flatten_list(df['action_type'].values, K)

# %% [markdown]
# ## Type of Terrorist Attack

# %% [markdown]
# Tabulate the frequency of different types of terrorist attacks.

# %%
from collections import Counter

Counter(action_type)
# Out:
# Counter({'Armed Assault': 211,
#          'Unknown': 64,
#          'Bombing/Explosion': 156,
#          'Assassination': 40,
#          'Facility/Infrastructure Attack': 47,
#          'NotSpecified': 50,
#          'Hijacking': 4,
#          'Unarmed Assault': 18,
#          'Kidnapping': 42,
#          'Barricade Incident': 1})

# %% [markdown]
# Generate a histogram of terrorist attacks.

# %%
# Import graph library
import seaborn as sns
import matplotlib.pyplot as plt 

# Set the font size
sns.set(font_scale = 1.5)

# Create figure frame 
plt.figure(figsize=(10,5))

# Plot the figure
chart = sns.countplot(x=action_type, palette = "Set2")

# Rotate labels in the X axis
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Armed Assault'),
#  Text(0, 0, 'Unknown'),
#  Text(0, 0, 'Bombing/Explosion'),
#  Text(0, 0, 'Assassination'),
#  Text(0, 0, 'Facility/Infrastructure Attack'),
#  Text(0, 0, 'NotSpecified'),
#  Text(0, 0, 'Hijacking'),
#  Text(0, 0, 'Unarmed Assault'),
#  Text(0, 0, 'Kidnapping'),
#  Text(0, 0, 'Barricade Incident')]

# %% [markdown]
# ## Country Specific

# %% [markdown]
# Now, let's analyze the distribution of terrorist attacks by counry.
#
# Start by creating the object 'COUNTRY' containing the list of annotated locations.

# %%
COUNTRIES = list(set(df["country"]))
COUNTRIES
# Out:
# ['india', 'pakistan', 'srilanka', 'afghanistan', 'bangladesh', 'nepal']

# %%
# Same here. Not sure what it does.

K = 10  # Is this taking 10 labels per column? Not sure how this works.

df_by_country = df[df['country'] == COUNTRIES[0]]

action = flatten_list(df_by_country['action_group'].values, K)
target = flatten_list(df_by_country['target_group'].values, K)
source = flatten_list(df_by_country['source_group'].values, K)
action_type = flatten_list(df_by_country['action_type'].values, K)

# %%
df.head()
# Out:
#       id  is_relevant                                      target  \
# 0  32355         True                  [Military Police, Rangers]
# 1  32398         True           [civilians, Security Forces, SFs]
# 2  29171         True                               [Nagas, Naga]
# 3  25445         True  [Artisan Restaurant, hostages, foreigners]
# 4  31739         True             [MQM, Muttahida Qaumi Movement]
#
#                                             source  \
# 0               [Lashkar e Jhangvi LeJ, militants]
# 1                                   [NotSpecified]
# 2            [Manipur Naga Peopleâ€™s Front, MNPF]
# 3  [suicide soldiers, attackers, suicide fighters]
# 4                                   [NotSpecified]
#
#                                  action          action_type  \
# 0             [gunned, killed, killing]      [Armed Assault]
# 1  [fighting, killed, wounded, killing]            [Unknown]
# 2   [explosion, bomb, exploded, attack]  [Bombing/Explosion]
# 3       [injuring, gun battle, killing]      [Armed Assault]
# 4                                [shot]      [Assassination]
#
#                                location            date     country  year  \
# 0                             [Karachi]    [December 6]    pakistan  2016
# 1                        [NotSpecified]   [December 20]    pakistan  2016
# 2                        [NotSpecified]     [August 30]       india  2016
# 3                               [Dhaka]  [August, 27th]  bangladesh  2016
# 4  [Sindh, Naeemabad, Karachi, Korangi]       [June 19]    pakistan  2016
#
#                                                 news  \
# 0  Two Lashkar e Jhangvi LeJ militants Asim alias...
# 1  The Commander Southern Command Lieutenant Gene...
# 2  Meanwhile the underground organization Manipur...
# 3  Islamic State IS in the latest issue of its on...
# 4  A senior Muttahida Qaumi Movement MQM worker i...
#
#                       target_group                   action_group  \
# 0       [Military Police, Rangers]           [gun attack, killed]
# 1                 [civilians, SFs]    [killed, wounded, fighting]
# 2                           [Naga]       [bomb, exploded, attack]
# 3  [civilians, Artisan Restaurant]  [gun attack, killed, injured]
# 4                            [MQM]                         [shot]
#
#                   source_group
# 0             [Militants, LeJ]
# 1               [NotSpecified]
# 2                       [MNPF]
# 3  [suicide bomber, attackers]
# 4               [NotSpecified]

# %% [markdown]
# Tabulate frequency of attacks per country

# %%
# Tabulate the action types (again ?)). That is not right
#Counter(action_type)

# I think we should tabulate countries here.

Counter(df['country'])
# Out:
# Counter({'pakistan': 140,
#          'india': 297,
#          'bangladesh': 21,
#          'nepal': 7,
#          'afghanistan': 38,
#          'srilanka': 1})

# %% [markdown]
# Plot frequency by country

# %%
# Bar plot by country

# Set the font size
sns.set(font_scale = 1.5)

# Create figure frame 
plt.figure(figsize=(10,5))

# Plot the figure
chart = sns.countplot(x=df['country'], palette = "Set2")

# Rotate labels in the X axis
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'pakistan'),
#  Text(0, 0, 'india'),
#  Text(0, 0, 'bangladesh'),
#  Text(0, 0, 'nepal'),
#  Text(0, 0, 'afghanistan'),
#  Text(0, 0, 'srilanka')]

# %% [markdown]
# ## Action-Type Count By Country

# %% [markdown]
# Generate graphs by country and type of action.
#
# First create another data frame.

# %%
df_action = df.copy()
df_action = df_action.explode('action_type')
df_action.head(5)
# Out:
#       id  is_relevant                                      target  \
# 0  32355         True                  [Military Police, Rangers]
# 1  32398         True           [civilians, Security Forces, SFs]
# 2  29171         True                               [Nagas, Naga]
# 3  25445         True  [Artisan Restaurant, hostages, foreigners]
# 4  31739         True             [MQM, Muttahida Qaumi Movement]
#
#                                             source  \
# 0               [Lashkar e Jhangvi LeJ, militants]
# 1                                   [NotSpecified]
# 2            [Manipur Naga Peopleâ€™s Front, MNPF]
# 3  [suicide soldiers, attackers, suicide fighters]
# 4                                   [NotSpecified]
#
#                                  action        action_type  \
# 0             [gunned, killed, killing]      Armed Assault
# 1  [fighting, killed, wounded, killing]            Unknown
# 2   [explosion, bomb, exploded, attack]  Bombing/Explosion
# 3       [injuring, gun battle, killing]      Armed Assault
# 4                                [shot]      Assassination
#
#                                location            date     country  year  \
# 0                             [Karachi]    [December 6]    pakistan  2016
# 1                        [NotSpecified]   [December 20]    pakistan  2016
# 2                        [NotSpecified]     [August 30]       india  2016
# 3                               [Dhaka]  [August, 27th]  bangladesh  2016
# 4  [Sindh, Naeemabad, Karachi, Korangi]       [June 19]    pakistan  2016
#
#                                                 news  \
# 0  Two Lashkar e Jhangvi LeJ militants Asim alias...
# 1  The Commander Southern Command Lieutenant Gene...
# 2  Meanwhile the underground organization Manipur...
# 3  Islamic State IS in the latest issue of its on...
# 4  A senior Muttahida Qaumi Movement MQM worker i...
#
#                       target_group                   action_group  \
# 0       [Military Police, Rangers]           [gun attack, killed]
# 1                 [civilians, SFs]    [killed, wounded, fighting]
# 2                           [Naga]       [bomb, exploded, attack]
# 3  [civilians, Artisan Restaurant]  [gun attack, killed, injured]
# 4                            [MQM]                         [shot]
#
#                   source_group
# 0             [Militants, LeJ]
# 1               [NotSpecified]
# 2                       [MNPF]
# 3  [suicide bomber, attackers]
# 4               [NotSpecified]

# %% [markdown]
# Now, pivot the database for countries and types of actions

# %%
aggregated = df_action.pivot_table(index = 'country', columns = 'action_type', aggfunc='size', fill_value=0)
aggregated
# Out:
# action_type  Armed Assault  Assassination  Barricade Incident  \
# country
# afghanistan              2              1                   0
# bangladesh               9              5                   0
# india                  129             10                   1
# nepal                    0              0                   0
# pakistan                71             24                   0
# srilanka                 0              0                   0
#
# action_type  Bombing/Explosion  Facility/Infrastructure Attack  Hijacking  \
# country
# afghanistan                 13                               3          1
# bangladesh                   7                               1          0
# india                       83                              38          2
# nepal                        5                               1          0
# pakistan                    48                               4          1
# srilanka                     0                               0          0
#
# action_type  Kidnapping  NotSpecified  Unarmed Assault  Unknown
# country
# afghanistan           4             5                0       17
# bangladesh            0             2                1        2
# india                35            34               17       38
# nepal                 0             1                0        0
# pakistan              3             8                0        6
# srilanka              0             0                0        1

# %% [markdown]
# Generate a plot for different actions per country

# %%
# Set the font size
sns.set(font_scale = 2)

# Create figure frame 
plt.figure(figsize=(10,5))

# Plot the figure
chart = aggregated.plot(kind='bar',stacked=True)

# %% [markdown]
# # Time Series

# %% [markdown]
# Create a data frame ofr time

# %%
df_time = df.copy()
df_time = df_time.explode('year')
df_time.head(5)
# Out:
#       id  is_relevant                                      target  \
# 0  32355         True                  [Military Police, Rangers]
# 1  32398         True           [civilians, Security Forces, SFs]
# 2  29171         True                               [Nagas, Naga]
# 3  25445         True  [Artisan Restaurant, hostages, foreigners]
# 4  31739         True             [MQM, Muttahida Qaumi Movement]
#
#                                             source  \
# 0               [Lashkar e Jhangvi LeJ, militants]
# 1                                   [NotSpecified]
# 2            [Manipur Naga Peopleâ€™s Front, MNPF]
# 3  [suicide soldiers, attackers, suicide fighters]
# 4                                   [NotSpecified]
#
#                                  action          action_type  \
# 0             [gunned, killed, killing]      [Armed Assault]
# 1  [fighting, killed, wounded, killing]            [Unknown]
# 2   [explosion, bomb, exploded, attack]  [Bombing/Explosion]
# 3       [injuring, gun battle, killing]      [Armed Assault]
# 4                                [shot]      [Assassination]
#
#                                location            date     country  year  \
# 0                             [Karachi]    [December 6]    pakistan  2016
# 1                        [NotSpecified]   [December 20]    pakistan  2016
# 2                        [NotSpecified]     [August 30]       india  2016
# 3                               [Dhaka]  [August, 27th]  bangladesh  2016
# 4  [Sindh, Naeemabad, Karachi, Korangi]       [June 19]    pakistan  2016
#
#                                                 news  \
# 0  Two Lashkar e Jhangvi LeJ militants Asim alias...
# 1  The Commander Southern Command Lieutenant Gene...
# 2  Meanwhile the underground organization Manipur...
# 3  Islamic State IS in the latest issue of its on...
# 4  A senior Muttahida Qaumi Movement MQM worker i...
#
#                       target_group                   action_group  \
# 0       [Military Police, Rangers]           [gun attack, killed]
# 1                 [civilians, SFs]    [killed, wounded, fighting]
# 2                           [Naga]       [bomb, exploded, attack]
# 3  [civilians, Artisan Restaurant]  [gun attack, killed, injured]
# 4                            [MQM]                         [shot]
#
#                   source_group
# 0             [Militants, LeJ]
# 1               [NotSpecified]
# 2                       [MNPF]
# 3  [suicide bomber, attackers]
# 4               [NotSpecified]

# %% [markdown]
# Pivot the database by year and country

# %%
time = df_time.pivot_table(index = 'year', columns = 'country', aggfunc='size', fill_value=0)
time
# Out:
# country  afghanistan  bangladesh  india  nepal  pakistan  srilanka
# year
# 2016               2          14    189      3       110         1
# 2017               0           7     60      4        18         0
# 2018              36           0     48      0        12         0

# %% [markdown]
# Plot time series

# %%
time = time.cumsum()
plt.figure();
time.plot.line();

# %% [markdown]
# # Source by country

# %% [markdown]
# Still is pretty messy.  We have to do a lot for data cleaning.
#
#
# Create dataframe by terrorist organization by country

# %%
df_source = df.copy()
df_source = df_source.explode('source_group')
df_source.head(5)
# Out:
#       id  is_relevant                                      target  \
# 0  32355         True                  [Military Police, Rangers]
# 0  32355         True                  [Military Police, Rangers]
# 1  32398         True           [civilians, Security Forces, SFs]
# 2  29171         True                               [Nagas, Naga]
# 3  25445         True  [Artisan Restaurant, hostages, foreigners]
#
#                                             source  \
# 0               [Lashkar e Jhangvi LeJ, militants]
# 0               [Lashkar e Jhangvi LeJ, militants]
# 1                                   [NotSpecified]
# 2            [Manipur Naga Peopleâ€™s Front, MNPF]
# 3  [suicide soldiers, attackers, suicide fighters]
#
#                                  action          action_type        location  \
# 0             [gunned, killed, killing]      [Armed Assault]       [Karachi]
# 0             [gunned, killed, killing]      [Armed Assault]       [Karachi]
# 1  [fighting, killed, wounded, killing]            [Unknown]  [NotSpecified]
# 2   [explosion, bomb, exploded, attack]  [Bombing/Explosion]  [NotSpecified]
# 3       [injuring, gun battle, killing]      [Armed Assault]         [Dhaka]
#
#              date     country  year  \
# 0    [December 6]    pakistan  2016
# 0    [December 6]    pakistan  2016
# 1   [December 20]    pakistan  2016
# 2     [August 30]       india  2016
# 3  [August, 27th]  bangladesh  2016
#
#                                                 news  \
# 0  Two Lashkar e Jhangvi LeJ militants Asim alias...
# 0  Two Lashkar e Jhangvi LeJ militants Asim alias...
# 1  The Commander Southern Command Lieutenant Gene...
# 2  Meanwhile the underground organization Manipur...
# 3  Islamic State IS in the latest issue of its on...
#
#                       target_group                   action_group  \
# 0       [Military Police, Rangers]           [gun attack, killed]
# 0       [Military Police, Rangers]           [gun attack, killed]
# 1                 [civilians, SFs]    [killed, wounded, fighting]
# 2                           [Naga]       [bomb, exploded, attack]
# 3  [civilians, Artisan Restaurant]  [gun attack, killed, injured]
#
#      source_group
# 0       Militants
# 0             LeJ
# 1    NotSpecified
# 2            MNPF
# 3  suicide bomber

# %% [markdown]
# Now, pivot the database for countries and terrorist organizations

# %%
source = df_source.pivot_table(index = 'country', columns = 'source_group', aggfunc='size', fill_value=0)
source
# Out:
# source_group  AQIS  ATJTMM  Airport Road  Al Qaeda  \
# country
# afghanistan      0       0             0         0
# bangladesh       0       0             0         0
# india            0       0             0         0
# nepal            0       1             0         0
# pakistan         2       0             1         1
# srilanka         0       0             0         0
#
# source_group  Armed Garo National Liberation Army  Armed men  BLA  CPI Maoist  \
# country
# afghanistan                                     0          0    0           0
# bangladesh                                      0          0    0           0
# india                                           1          0    0         100
# nepal                                           0          0    0           0
# pakistan                                        0          1    2           0
# srilanka                                        0          0    0           0
#
# source_group  CPN Maoist  Cadres  ...  miscreant  operational commander  \
# country                           ...
# afghanistan            0       0  ...          0                      0
# bangladesh             0       0  ...          0                      1
# india                  0       1  ...          2                      0
# nepal                  2       1  ...          0                      0
# pakistan               0       0  ...          2                      0
# srilanka               0       0  ...          0                      0
#
# source_group  persons  rebels  rival  sniper  spokesman  suicide bomber  \
# country
# afghanistan         0       0      0       0          0               1
# bangladesh          0       0      0       0          0               2
# india               1       2      1       1          0               2
# nepal               0       0      0       0          0               0
# pakistan            1       0      0       0          1               3
# srilanka            0       0      0       0          0               0
#
# source_group  suspected millitants  terrorist
# country
# afghanistan                      0          0
# bangladesh                       2          0
# india                            2          3
# nepal                            0          0
# pakistan                         8          7
# srilanka                         0          0
#
# [6 rows x 101 columns]

# %% [markdown]
# Generate a plot for different actions per country

# %%
# Set the font size
sns.set(font_scale = 2)

# Create figure frame 
plt.figure(figsize=(10,5))


# Plot Afghanistan
df0=source.iloc[0,:]                                        # Select row for Afghanistan 
chart = df0[df0 > 0].plot(kind='bar', title="Afghanistan")  # Plot values grater than zero

# %%
# Set the font size
sns.set(font_scale = 2)

# Create figure frame 
plt.figure(figsize=(10,5))

# Plot Bangladesh
df1=source.iloc[1,:]                                        # Select row for Bangladesh 
chart = df1[df1 > 0].plot(kind='bar', title="Bangladesh")  # Plot values grater than zero

# %%
# Set the font size
#sns.set(font_scale = 2)

# Create figure frame 
#plt.figure(figsize=(10,5))

# Plot India
df2=source.iloc[2,:]                                  # Select row for India 
chart = df2[df2 > 1].plot(kind='bar', title="India")  # Plot values grater than zero

# %%
# Set the font size
sns.set(font_scale = 2)

# Create figure frame 
plt.figure(figsize=(10,5))

# Plot Nepal
df3=source.iloc[3,:]                                  # Select row for Nepal 
chart = df3[df3 > 0].plot(kind='bar', title="Nepal")  # Plot values grater than zero

# %%
# Set the font size
sns.set(font_scale = 1)

# Create figure frame 
plt.figure(figsize=(10,5))

# Plot Pakistan
df4=source.iloc[4,:]                                     # Select row for Pakistan 
chart = df4[df4 > 0].plot(kind='bar', title="Pakistan")  # Plot values grater than zero

# %%
# Set the font size
sns.set(font_scale = 2)

# Create figure frame 
plt.figure(figsize=(10,5))

# Plot Pakistan
df5=source.iloc[5,:]                                     # Select row for Pakistan 
chart = df5[df5 > 0].plot(kind='bar', title="Sri Lanka")  # Plot values grater than zero

# %% [markdown]
# # Target By Country

# %%
df_target = df.copy()
df_target = df_target.explode('target_group')
df_target.head(5)
# Out:
#       id  is_relevant                             target  \
# 0  32355         True         [Military Police, Rangers]
# 0  32355         True         [Military Police, Rangers]
# 1  32398         True  [civilians, Security Forces, SFs]
# 1  32398         True  [civilians, Security Forces, SFs]
# 2  29171         True                      [Nagas, Naga]
#
#                                   source  \
# 0     [Lashkar e Jhangvi LeJ, militants]
# 0     [Lashkar e Jhangvi LeJ, militants]
# 1                         [NotSpecified]
# 1                         [NotSpecified]
# 2  [Manipur Naga Peopleâ€™s Front, MNPF]
#
#                                  action          action_type        location  \
# 0             [gunned, killed, killing]      [Armed Assault]       [Karachi]
# 0             [gunned, killed, killing]      [Armed Assault]       [Karachi]
# 1  [fighting, killed, wounded, killing]            [Unknown]  [NotSpecified]
# 1  [fighting, killed, wounded, killing]            [Unknown]  [NotSpecified]
# 2   [explosion, bomb, exploded, attack]  [Bombing/Explosion]  [NotSpecified]
#
#             date   country  year  \
# 0   [December 6]  pakistan  2016
# 0   [December 6]  pakistan  2016
# 1  [December 20]  pakistan  2016
# 1  [December 20]  pakistan  2016
# 2    [August 30]     india  2016
#
#                                                 news     target_group  \
# 0  Two Lashkar e Jhangvi LeJ militants Asim alias...  Military Police
# 0  Two Lashkar e Jhangvi LeJ militants Asim alias...          Rangers
# 1  The Commander Southern Command Lieutenant Gene...        civilians
# 1  The Commander Southern Command Lieutenant Gene...              SFs
# 2  Meanwhile the underground organization Manipur...             Naga
#
#                   action_group      source_group
# 0         [gun attack, killed]  [Militants, LeJ]
# 0         [gun attack, killed]  [Militants, LeJ]
# 1  [killed, wounded, fighting]    [NotSpecified]
# 1  [killed, wounded, fighting]    [NotSpecified]
# 2     [bomb, exploded, attack]            [MNPF]

# %%
target = df_target.pivot_table(index = 'country', columns = 'target_group', aggfunc='size', fill_value=0)
target
# Out:
# target_group  ALP  ANP  AP  AR  ASI  Afghan consulate official  Army  \
# country
# afghanistan     2    0   0   0    0                          0     2
# bangladesh      0    0   0   0    0                          0     0
# india           0    0   1   8    2                          0    27
# nepal           0    0   0   0    0                          0     0
# pakistan        0    1   0   0    2                          1     2
# srilanka        0    0   0   0    0                          0     0
#
# target_group  Army base  Army vehicle  Artisan Restaurant  ...  tractor  \
# country                                                    ...
# afghanistan           0             0                   0  ...        0
# bangladesh            0             0                   2  ...        0
# india                 1             1                   0  ...        3
# nepal                 0             0                   0  ...        0
# pakistan              0             1                   0  ...        0
# srilanka              0             0                   0  ...        0
#
# target_group  tractors  trade  tribals  troopers  truck  truck driver  trucks  \
# country
# afghanistan          0      0        0         0      0             0       0
# bangladesh           0      0        0         0      0             0       0
# india                2      1        1         8      3             1       3
# nepal                0      0        0         0      0             0       0
# pakistan             0      0        0         3      0             0       0
# srilanka             0      0        0         0      0             0       0
#
# target_group  vehicle  water tank
# country
# afghanistan         1           0
# bangladesh          0           0
# india              16           1
# nepal               2           0
# pakistan            3           0
# srilanka            0           0
#
# [6 rows x 218 columns]

# %%
# Set the font size
sns.set(font_scale = 2)

# Create figure frame 
plt.figure(figsize=(10,5))

# Plot Bangladesh
df1=target.iloc[0,:]                                        # Select row for Afghanistan 
chart = df1[df1 > 0].plot(kind='bar', title="Afghanistan")  # Plot values grater than zero

# %%
# Set the font size
sns.set(font_scale = 2)

# Create figure frame 
plt.figure(figsize=(10,5))

# Plot Bangladesh
df1=target.iloc[1,:]                                        # Select row for Afghanistan 
chart = df1[df1 > 0].plot(kind='bar', title="Bangladesh")  # Plot values grater than zero

# %%
# Plot India
df2=target.iloc[2,:]                                  # Select row for India 
chart = df2[df2 > 1].plot(kind='bar', title="India")  # Plot values grater than zero

# %%
# Plot Nepal
df3=target.iloc[3,:]                                  # Select row for Nepal 
chart = df3[df3 > 0].plot(kind='bar', title="Nepal")  # Plot values grater than ze

# %%
# Plot Nepal
df3=target.iloc[4,:]                                  # Select row for Pakistan 
chart = df3[df3 > 1].plot(kind='bar', title="Pakistan")  # Plot values grater than ze

# %%
# Plot Nepal
df3=target.iloc[5,:]                                  # Select row for Srilanka 
chart = df3[df3 > 0].plot(kind='bar', title="Srilanka")  # Plot values grater than ze

# %% [markdown]
# # Action By Country

# %%
df_action = df.copy()
df_action = df_action.explode('action_group')
df_action.head(5)
# Out:
#       id  is_relevant                             target  \
# 0  32355         True         [Military Police, Rangers]
# 0  32355         True         [Military Police, Rangers]
# 1  32398         True  [civilians, Security Forces, SFs]
# 1  32398         True  [civilians, Security Forces, SFs]
# 1  32398         True  [civilians, Security Forces, SFs]
#
#                                source                                action  \
# 0  [Lashkar e Jhangvi LeJ, militants]             [gunned, killed, killing]
# 0  [Lashkar e Jhangvi LeJ, militants]             [gunned, killed, killing]
# 1                      [NotSpecified]  [fighting, killed, wounded, killing]
# 1                      [NotSpecified]  [fighting, killed, wounded, killing]
# 1                      [NotSpecified]  [fighting, killed, wounded, killing]
#
#        action_type        location           date   country  year  \
# 0  [Armed Assault]       [Karachi]   [December 6]  pakistan  2016
# 0  [Armed Assault]       [Karachi]   [December 6]  pakistan  2016
# 1        [Unknown]  [NotSpecified]  [December 20]  pakistan  2016
# 1        [Unknown]  [NotSpecified]  [December 20]  pakistan  2016
# 1        [Unknown]  [NotSpecified]  [December 20]  pakistan  2016
#
#                                                 news  \
# 0  Two Lashkar e Jhangvi LeJ militants Asim alias...
# 0  Two Lashkar e Jhangvi LeJ militants Asim alias...
# 1  The Commander Southern Command Lieutenant Gene...
# 1  The Commander Southern Command Lieutenant Gene...
# 1  The Commander Southern Command Lieutenant Gene...
#
#                  target_group action_group      source_group
# 0  [Military Police, Rangers]   gun attack  [Militants, LeJ]
# 0  [Military Police, Rangers]       killed  [Militants, LeJ]
# 1            [civilians, SFs]       killed    [NotSpecified]
# 1            [civilians, SFs]      wounded    [NotSpecified]
# 1            [civilians, SFs]     fighting    [NotSpecified]

# %%
action = df_action.pivot_table(index = 'country', columns = 'action_group', aggfunc='size', fill_value=0)
action
# Out:
# action_group  Chinese grenade  Firing  IED  Injured  NotSpecified  \
# country
# afghanistan                 0       0    1        0             0
# bangladesh                  0       0    0        0             0
# india                       1       0   27        1             4
# nepal                       0       0    4        0             1
# pakistan                    0       1   11        0             1
# srilanka                    0       0    0        0             0
#
# action_group  Under Barrel Grenades  VBIED  a  abduct  ablaze  ...  taken  \
# country                                                        ...
# afghanistan                       0      3  0       3       0  ...      0
# bangladesh                        0      0  0       0       0  ...      0
# india                             1      0  1      36      28  ...      1
# nepal                             0      0  0       0       0  ...      0
# pakistan                          0      1  0       3       0  ...      0
# srilanka                          0      0  0       0       0  ...      0
#
# action_group  tear gas  thrashed  took control  torched  tortured  triggered  \
# country
# afghanistan          0         0             1        1         0          0
# bangladesh           0         0             0        0         0          0
# india                1         3             0        6         1          4
# nepal                0         0             0        0         0          0
# pakistan             0         0             0        0         0          0
# srilanka             0         0             0        0         0          0
#
# action_group  vehicle  weapons  wounded
# country
# afghanistan         0        0        3
# bangladesh          0        0        0
# india               1        1        2
# nepal               0        0        0
# pakistan            0        0        4
# srilanka            0        0        0
#
# [6 rows x 103 columns]

# %%
# Set the font size
sns.set(font_scale = 2)

# Create figure frame 
plt.figure(figsize=(10,5))

# Plot Bangladesh
df1=action.iloc[0,:]                                        # Select row for Afghanistan 
chart = df1[df1 > 0].plot(kind='bar', title="Afghanistan")  # Plot values grater than zero

# %%
# Set the font size
sns.set(font_scale = 2)

# Create figure frame 
plt.figure(figsize=(10,5))

# Plot Bangladesh
df1=action.iloc[1,:]                                        # Select row for Bangladesh
chart = df1[df1 > 0].plot(kind='bar', title="Bangladesh")  # Plot values grater than zero

# %%
# Set the font size
sns.set(font_scale = 2)

# Create figure frame 
plt.figure(figsize=(10,5))

# Plot Bangladesh
df1=action.iloc[2,:]                                        # Select row for India
chart = df1[df1 > 1].plot(kind='bar', title="India")  # Plot values grater than zero

# %%
# Set the font size
sns.set(font_scale = 2)

# Create figure frame 
plt.figure(figsize=(10,5))

# Plot Bangladesh
df1=action.iloc[3,:]                                        # Select row for Nepal
chart = df1[df1 > 0].plot(kind='bar', title="Nepal")  # Plot values grater than zero

# %%
# Set the font size
sns.set(font_scale = 2)

# Create figure frame 
plt.figure(figsize=(10,5))

# Plot Bangladesh
df1=action.iloc[4,:]                                        # Select row for Pakistan
chart = df1[df1 > 1].plot(kind='bar', title="Pakistan")  # Plot values grater than zero

# %%
# Set the font size
sns.set(font_scale = 2)

# Create figure frame 
plt.figure(figsize=(10,5))

# Plot Bangladesh
df1=action.iloc[5,:]                                        # Select row for Srilanka
chart = df1[df1 > 0].plot(kind='bar', title="Srilanka")  # Plot values grater than zero
